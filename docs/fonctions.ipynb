# %% [markdown]
# <a href="https://colab.research.google.com/github/lilabidi/Maths-seconde-Python/blob/main/docs/fonctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# |Eddy Labidi |  Fonctions  | <img src="https://resources.finalsite.net/images/f_auto,q_auto,t_image_size_4/v1600275778/lyceelondres/q3q3xqfrko9gwz1m7f8k/Logo-Lycee.png" alt="logo" width="100"/>|
# | :--- |:---:| ---:|
# | Algo  | Langage Python | Lycée international de Londres  |

# %% [markdown]
# # Fonctions

# %% [markdown]
# ## TP 4
#
# ![115669-1.gif](data:image/gif;base64,...)

# %% [markdown]
# ### Méthode par balayage

# %%
x = 4.0
pas = 0.1

for i in range(10):
    print(round(x, 2), round(x**3 + x, 2))
    x = x + pas
# Out:
# 4.0 68.0
# 4.1 73.02
# 4.2 78.29
# 4.3 83.81
# 4.4 89.58
# 4.5 95.62
# 4.6 101.94
# 4.7 108.52
# 4.8 115.39
# 4.9 122.55

# %% [markdown]
# ### Méthode par dichotomie

# %%
a = 4
b = 5

while b - a > 0.1:
    c = (a + b)/2
    if c**3 + c > 100:
        b = c
    else:
        a = c

print(a)
print(b)
# Out:
# 4.5625
# 4.625

# %% [markdown]
# ### Autre méthode
